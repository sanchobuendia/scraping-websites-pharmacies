# %%
import pandas as pd
import json
from results_prices import Results
import re

pd.set_option("display.max_colwidth", None)

# %%
df = pd.read_excel("prices_fake_allsites.xlsx")

path_dict = "dict_url.json"
with open(path_dict, "r") as json_file:
    dict_url = json.load(json_file)

# %%
# df = df.head(3)
out = Results(
    df, dict_url=dict_url, openai_api_key="", openai_api_base="", openai_api_version=""
)
out = out.output()
out.head(30)
# Out:
#                     rede       mes   ano periodo de exposicao tipo de acao  \
# 0       drogariasaopaulo   January  2023                   Q1       Type A
# 1                PACHECO  February  2023                   Q1       Type B
# 2                 PANVEL     March  2023                   Q2       Type A
# 3                 ARAÚJO     April  2023                   Q2       Type B
# 4      DROGARIA VENANCIO   January  2023                   Q1       Type A
# 5            PAGUE MENOS  February  2023                   Q1       Type B
# 6                INDIANA     March  2023                   Q2       Type A
# 7                 NISSEI     April  2023                   Q2       Type B
# 8             EXTRAFARMA   January  2023                   Q1       Type A
# 9                 DROGAL  February  2023                   Q1       Type B
# 10        DROGARIA GLOBO     March  2023                   Q2       Type A
# ...
