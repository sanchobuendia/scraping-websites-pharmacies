# %%
import pandas as pd
import numpy as np

# %%
data = {
    'rede': ['PACHECO', 'ARAÚJO', 'INDIANA'],
    'site': ['https://www.drogariaspacheco.com.br/', 'https://www.araujo.com.br/', 'https://www.farmaciaindiana.com.br/'],
    'local_site': ['pagina principal', 'medicamentos', 'pagina principal'],
    'target': ["target_pacheco_True.jpg", "target_araujo_False.jpg", "target_indiana_False.jpg"],
    'match': [False, False, False]
}
df_images_fake = pd.DataFrame(data)
excel_file_name = 'planilha_imagens_fake.xlsx'
df_images_fake.to_excel(excel_file_name, index=False)

# %%
df = pd.read_excel("planilha_imagens_fake.xlsx")
df.head()
# Out:
#       rede                                  site        local_site  \
# 0  PACHECO  https://www.drogariaspacheco.com.br/  pagina principal
# 1   ARAÚJO            https://www.araujo.com.br/      medicamentos
# 2  INDIANA   https://www.farmaciaindiana.com.br/  pagina principal
#
#                      target  match
# 0   target_pacheco_True.jpg  False
# 1   target_araujo_False.jpg  False
# 2  target_indiana_False.jpg  False

# %%
data = {
    'rede': ['PANVEL', 'DROGAL', 'RAIA', 'DROGARIA ROSARIO'],
    'mes': ['October', 'October', 'October', 'October'],
    'ano': [2023, 2023, 2023, 2023],
    'periodo de exposicao': ['Q1', 'Q1', 'Q2', 'Q2'],
    'tipo de acao': ['Type A', 'Type B', 'Type A', 'Type B'],
    'unidade': ['Unit 1', 'Unit 2', 'Unit 1', 'Unit 2'],
    'produto': ['Fosfato Sodico Prednisolona 3mg/ml Solução Oral 60ml Genérico Biosintética', 'DayVit Kids 120ml', 'Decongex Plus Maleato de Clorfeniramina 12mg + Cloridrato Fenillefrina 15mg 12 comprimidos', 'Biozinc Kids 2mg Solução Oral 75ml'],
    'preco do produto': [13.69, 49.59 , 25.69, 29.90],
    'url_site': ['https://www.panvel.com/', 'https://www.drogal.com.br/', 'https://www.drogaraia.com.br/', 'https://www.drogariarosario.com.br/']
}

df_price_fake = pd.DataFrame(data)
excel_file_name = 'prices_fake_4sites.xlsx'
df_price_fake.to_excel(excel_file_name, index=False)

# %%
df = pd.read_excel("prices_fake.xlsx")
df.head()
# Out:
#                rede      mes   ano periodo de exposicao tipo de acao unidade  \
# 0            PANVEL  October  2023                   Q1       Type A  Unit 1
# 1            DROGAL  October  2023                   Q1       Type B  Unit 2
# 2              RAIA  October  2023                   Q2       Type A  Unit 1
# 3  DROGARIA ROSARIO  October  2023                   Q2       Type B  Unit 2
#
#                                              produto  preco do produto  \
# 0  Fosfato Sodico Prednisolona 3mg/ml Solução Ora...             13.69
# 1                                  DayVit Kids 120ml             49.59
# 2  Decongex Plus Maleato de Clorfeniramina 12mg +...             25.69
# 3                 Biozinc Kids 2mg Solução Oral 75ml             29.90
#
#                               url_site
# 0              https://www.panvel.com/
# 1           https://www.drogal.com.br/
# 2        https://www.drogaraia.com.br/
# 3  https://www.drogariarosario.com.br/

# %%
import pandas as pd

data = {
    'rede': ['drogariasaopaulo', 'PACHECO', 'PANVEL', 'ARAÚJO', 'DROGARIA VENANCIO','PAGUE MENOS', 'INDIANA', 'NISSEI', 'EXTRAFARMA', 'DROGAL', 'DROGARIA GLOBO','RAIA', 'DROGASIL', 'drogasmil', 'DROGARIA TAMOIO', 'farmalife', 'DROGARIA ROSARIO','PRECO POPULAR', 'DROGARIA CATARINENSE'],
    'mes': ['January', 'February', 'March', 'April', 'January', 'February', 'March', 'April', 'January', 'February', 'March', 'April', 'January', 'February', 'March', 'April', 'January', 'February', 'March'],
    'ano': [2023, 2023, 2023, 2023, 2023, 2023, 2023, 2023, 2023, 2023, 2023, 2023, 2023, 2023, 2023, 2023, 2023, 2023,2023],
    'periodo de exposicao': ['Q1', 'Q1', 'Q2', 'Q2', 'Q1', 'Q1', 'Q2', 'Q2', 'Q1', 'Q1', 'Q2', 'Q2', 'Q1', 'Q1', 'Q2', 'Q2', 'Q1', 'Q1', 'Q2'],
    'tipo de acao': ['Type A', 'Type B', 'Type A', 'Type B', 'Type A', 'Type B', 'Type A', 'Type B', 'Type A', 'Type B', 'Type A', 'Type B', 'Type A', 'Type B', 'Type A', 'Type B', 'Type A', 'Type B', 'Type A'],
    'unidade': ['Unit 1', 'Unit 2', 'Unit 1', 'Unit 2', 'Unit 1', 'Unit 2', 'Unit 1', 'Unit 2', 'Unit 1', 'Unit 2', 'Unit 1', 'Unit 2', 'Unit 1', 'Unit 2', 'Unit 1', 'Unit 2', 'Unit 1', 'Unit 2', 'Unit 1'],
    'produto': ['Flogoral Aché Menta Spray', 'Biozinc Kids Aché 75ml', 'Vitamina E Vita E Ciclos Ache 60 Capsulas', 'Colidis Gotas 10ml', 'Colidis Ache 5ml', 'Sany D 1.000ui Com 30 Cápsulas', 'Prohn 30 Cápsulas', 'Xarope Decongex Plus Achê 120ml', 'Hidratante Labial Carmed Fini Beijos Efeito Gloss 10g', 'Artrogen Duo 30 Sachês', 'Colidis Gotas 10Ml', 'Decongex Plus Maleato de Clorfeniramina', 'Oxalato de Escitalopram 10mg 60 Comprimidos', 'Descongex Plus - 12 comprimidos', 'Flagass 75mg/ml Emulsão Or 10ml', 'COLIDIS GOTAS FRX10ML', 'Biofenac Aerosol 11,6Mg 60G', 'Simeticona Biosintética 125mg Com 10 Cápsulas', 'Simeticona Biosintética 125mg Com 10 Cápsulas'],
    'preco do produto': [31.69, 33.05, 53.49, 163.09 , 118.97, 19.89, 128.29 , 19.90 , 24.90, 148.99 , 145.19, 25.69, 46.18, 21.99, 16.19, 196.90, 25.99, 5.17, 5.17],
    'url_site': ['https://www.drogariasaopaulo.com.br/', 'https://www.drogariaspacheco.com.br/', 'https://www.panvel.com/', 'https://www.araujo.com.br/', 'https://www.drogariavenancio.com.br/', 'https://www.paguemenos.com.br/', 'https://www.farmaciaindiana.com.br/', 'https://www.farmaciasnissei.com.br/', 'https://www.extrafarma.com.br/', 'https://www.drogal.com.br/', 'https://www.drogariaglobo.com.br/', 'https://www.drogaraia.com.br/', 'https://www.drogasil.com.br/', 'https://www.drogasmil.com.br/', 'https://www.drogariastamoio.com.br/', 'https://www.farmalife.com.br/', 'https://www.drogariarosario.com.br/', 'https://www.precopopular.com.br/', 'https://www.drogariacatarinense.com.br/']
}

df_price_fake = pd.DataFrame(data)
excel_file_name = 'prices_fake_allsites.xlsx'
df_price_fake.to_excel(excel_file_name, index=False)
